# %% [markdown]
# # Instituto Tecnológico de Monterrey
# # Ciencia y analítica de datos
# # A01793599 Gustavo René Ramos Ojeda
#
# # Módulo 3 - Exploratory Data Analysis

# %%
# A01793599 - Initial part of the lab

import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns

# A01793599 - Initining dataframe from file
filename="automobileEDA.csv"
df = pd.read_csv(filename)
df.head()

print( df.dtypes )
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# Question #1 - Tipo de datos de la columna "peak-rpm" ?

# %%
print ("ValueType for column peak-rpm: " + str(df["peak-rpm"].dtype))


# Just for calculating correlation
df.corr( numeric_only=True)
# Out:
# ValueType for column peak-rpm: float64
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Question #2 - Correlación entre las columnas: bore, stroke, compression-ratio, and horsepower

# %%
# A01793599 - Getting correlation between variables in dataframe

df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# Question #3a - Correlación entre x="stroke" e y="price"

# %%
# A01793599 - Obeniendo la correlación entre stroke y price

df[["stroke","price"]].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# Question #3b - Gráfica para identificar relación lineal entre x="stroke" e y="price"

# %%
# A01793599 - Mostrando la relación gráfica entre stroke y price

sns.regplot(x="stroke", y="price", data=df)
# Out:
# <AxesSubplot: xlabel='stroke', ylabel='price'>

# %% [markdown]
# Question #4 - Encontrar precio promedio en función de la variable "body-style"

# %%
df_agrupacion = df[['body-style','price']]
groupedMean = df_agrupacion.groupby(['body-style'], as_index= False).mean()
groupedMean
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# Ejercicios sobre correlación y causalidad

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270733218e-20

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8095745670036559  with a P-value of P =  6.369057428260101e-48

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483638  with a P-value of P =  8.016477466159556e-30

# %% [markdown]
# Ejercicios sobre ANOVA

# %%
df_agrupacion = df[['drive-wheels', 'price']]
grouped_test2=df_agrupacion[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.head(2)

df_agrupacion
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# ..           ...      ...
# 196          rwd  16845.0
# 197          rwd  19045.0
# 198          rwd  21485.0
# 199          rwd  22470.0
# 200          rwd  22625.0
#
# [201 rows x 2 columns]

# %%
grouped_test2.get_group('4wd')['price']

f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23
